# %%
import pandas as pd
import numpy as np
import os
import sys
# !pip -qq install psutil
import psutil
from time import time, sleep
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import resource
from glob import glob
from IPython.display import clear_output
from NSGPy.NumPy import LLS

# %% [markdown]
# ## Data preperation

# %%
main_path = '~/Nonstat-exps/gp_extra/'
df = pd.read_csv(main_path+'data/beijing_AQI.csv').rename(columns={'PM25_Concentration':'PM25','longitude':'long','latitude':'lat'})
df = df.set_index('time').sort_index()
print('unique timestamps are',len(df.index.unique()))
useful_ts = []
for ts in df.index.unique():
  if(len(df.loc[ts])==36):
    useful_ts.append(ts)
df = df.loc[useful_ts]
df['PM25'] = df['PM25'].astype(float)
print('unique timestamps after removing missing entry time-stamps are',len(useful_ts))
df.columns

n_ts = len(useful_ts)
K = 3 #  Number of folds
n_val = 6 # Number of validation stations

splitter = KFold(K, shuffle=True, random_state=0)
stations = np.sort(df['station_id'].unique())
folds={i:{'train':None,'val':None,'test':None} for i in range(K)}
for i, (train_val, test) in enumerate(splitter.split(stations)):
    folds[i]['train'] = stations[train_val[:-n_val]]
    folds[i]['val'] = stations[train_val[-n_val:]]
    folds[i]['test'] = stations[test]
    
###########################
# Data preperation
###########################
data = {i:{'train_Xy':None,'val_Xy':None,'test_Xy':None} for i in range(K)}
for fold in range(K):
    for part in ['train','val','test']:
        data[fold][part+'_Xy'] = (df[df.station_id.isin(folds[fold][part])][['long', 'lat']], 
                                  df[df.station_id.isin(folds[fold][part])][['PM25']])
# Out:
# unique timestamps are 7460
# unique timestamps after removing missing entry time-stamps are 2132

# %% [markdown]
# ## df to save all results

# %%
n_time_i = np.array(df.index.unique().tolist()*3).reshape(1,-1)
n_time_id = np.array(list(range(len(df.index.unique())))*3).reshape(1,-1)
n_fold_i = np.concatenate([np.ones(n_time_i.shape[1]//3)*0, 
                           np.ones(n_time_i.shape[1]//3)*1, 
                           np.ones(n_time_i.shape[1]//3)*2]).reshape(1,-1).astype(int)
mult_i = np.concatenate([n_time_id, n_time_i, n_fold_i], axis=0)
master_df = pd.DataFrame(index=pd.MultiIndex.from_arrays(mult_i))

# %% [markdown]
# ## K fold GP-LLS - matern

# %%
path = 'results/raw_gp_lls_self/'
kernel = 'matern'
n_ts = 24

# %%
# Check if works
# !python scripts/process_gp_lls_self.py 13 1 matern

# %% [markdown]
# ### Training

# %%
init = time()
jobs = []
for fold in range(K):
    for ts in range(n_ts):
        jobs.append('python scripts/process_gp_lls_self.py {0} {1} {2}'.format(ts, fold, kernel))

print('starting',len(jobs),'jobs on',psutil.cpu_count(),'CPUs')
sleep(1)
n_splits = len(jobs)//64+1
for b_id, batch in enumerate(np.array_split(jobs, n_splits)):
    print('start',b_id+1,'of',n_splits)
    print('length of batch=',len(batch))
    os.system(' | '.join(batch))
    clear_output(wait=True)
    print('end',b_id+1,'of',n_splits)
print((time()-init)/60, 'all fold complete')
# Out:
# end 2 of 2
# 4.020998648802439 all fold complete

# %% [markdown]
# ### RMSE calculation

# %%
path = 'results/raw_gp_lls_self/'+kernel+'/'
name = 'lls_matern'
master_df[name] = None
preds = []
tests = []
mean_rmse_per_fold = []
success = []
n_fold_rmse = []
for fold in folds:
    hyp = []
    fold_rmse = []
    tmp_preds_y = []
    tmp_models = []
    tmp_tests_y = []
    tmp_tests_x = []
    tmp_train_Xy = []
    for ts_n, ts in enumerate(df.index.unique()[:n_ts]):
        try:
            tmp = pd.read_pickle(path+'ts_'+str(ts)+'_fold_'+str(fold))
            hyp.append(tmp['best_hyperpara']['N'])
            preds.append(tmp['pred_y'].squeeze())
            tests.append(tmp['test_y'].squeeze())
            tmp_models.append(tmp['best_model'])
            tmp_train_Xy.append(tmp['train_Xy'])
            tmp_tests_x.append(tmp['test_Xy'][0].squeeze())
            tmp_preds_y.append(tmp['pred_y'].squeeze())
            tmp_tests_y.append(tmp['test_y'].squeeze())
            success.append(path+'ts_'+str(ts)+'_fold_'+str(fold))
            fold_rmse.append(mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False))
            master_df.loc[(str(ts_n), str(ts), str(fold)),name] = mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False)
            master_df.loc[(str(ts_n), str(ts), str(fold)),name+'_model'] = tmp['best_model']
        except:
            pass
    print('Fold',fold,'mean_rmse',np.mean(fold_rmse))
    mean_rmse_per_fold.append(np.mean(fold_rmse))
    print("Fold",fold,'individual_rmse',mean_squared_error(np.array(tmp_tests_y).flatten(), np.array(tmp_preds_y).flatten(), squared=False))
print("Overall RMSE (individual)", mean_squared_error(np.array(tests).flatten(), np.array(preds).flatten(), squared=False))
print("Overall RMSE (mean of folds)", np.mean(mean_rmse_per_fold))
pd.Series(hyp).value_counts()
# Out:
# Fold 0 mean_rmse 31.36015354121044
# Fold 0 individual_rmse 36.16972386541926
# Fold 1 mean_rmse 30.34882366479919
# Fold 1 individual_rmse 35.834641038964875
# Fold 2 mean_rmse 32.99720108554077
# Fold 2 individual_rmse 40.56519243885994
# Overall RMSE (individual) 37.589689539466235
# Overall RMSE (mean of folds) 31.56872609718347
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# 8    7
# 9    4
# 4    4
# 3    4
# 7    3
# 6    1
# dtype: int64

# %% [markdown]
# ## Manual check (Misc.)

# %%
import matplotlib.pyplot as plt
N = 0
dim = 0
plt.plot()
plt.scatter(tmp_train_Xy[N][0][:,dim], tmp_train_Xy[N][1],label='train')
plt.scatter(tmp_tests_x[N][:,dim], tmp_tests_y[N],label='test')
plt.scatter(tmp_tests_x[N][:,dim], tmp_preds_y[N],label='pred')
plt.legend();

# %%
# pd.to_pickle(success, 'results/sync.pickle')

# %% [markdown]
# ## K fold GP-LLS - rbf

# %%
path = 'results/raw_gp_lls_self/'
kernel = 'rbf'
n_ts = 24

# %% [markdown]
# ### Training

# %%
init = time()
jobs = []
for fold in range(K):
    for ts in range(n_ts):
        jobs.append('python scripts/process_gp_lls_self.py {0} {1} {2}'.format(ts, fold, kernel))

print('starting',len(jobs),'jobs on',psutil.cpu_count(),'CPUs')
sleep(1)
n_splits = len(jobs)//64+1
for b_id, batch in enumerate(np.array_split(jobs, n_splits)):
    print('start',b_id+1,'of',n_splits)
    print('length of batch=',len(batch))
    os.system(' | '.join(batch))
    clear_output(wait=True)
    print('end',b_id+1,'of',n_splits)
print((time()-init)/60, 'minutes. all fold complete')
# Out:
# end 2 of 2
# 3.3839593132336936 minutes. all fold complete

# %% [markdown]
# ### RMSE calculation

# %%
path = 'results/raw_gp_lls_self/'+kernel+'/'
name = 'lls_rbf'
master_df[name] = None
preds = []
tests = []
mean_rmse_per_fold = []
success = []
n_fold_rmse = []
for fold in folds:
    hyp = []
    fold_rmse = []
    tmp_preds_y = []
    tmp_models = []
    tmp_tests_y = []
    tmp_tests_x = []
    tmp_train_Xy = []
    for ts_n, ts in enumerate(df.index.unique()[:n_ts]):
        try:
            tmp = pd.read_pickle(path+'ts_'+str(ts)+'_fold_'+str(fold))
            hyp.append(tmp['best_hyperpara']['N'])
            preds.append(tmp['pred_y'].squeeze())
            tests.append(tmp['test_y'].squeeze())
            tmp_models.append(tmp['best_model'])
            tmp_train_Xy.append(tmp['train_Xy'])
            tmp_tests_x.append(tmp['test_Xy'][0].squeeze())
            tmp_preds_y.append(tmp['pred_y'].squeeze())
            tmp_tests_y.append(tmp['test_y'].squeeze())
            success.append(path+'ts_'+str(ts)+'_fold_'+str(fold))
            fold_rmse.append(mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False))
            master_df.loc[(str(ts_n), str(ts), str(fold)),name] = mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False)
        except:
            pass
    print('Fold',fold,'mean_rmse',np.mean(fold_rmse))
    mean_rmse_per_fold.append(np.mean(fold_rmse))
    print("Fold",fold,'individual_rmse',mean_squared_error(np.array(tmp_tests_y).flatten(), np.array(tmp_preds_y).flatten(), squared=False))
print("Overall RMSE (individual)", mean_squared_error(np.array(tests).flatten(), np.array(preds).flatten(), squared=False))
print("Overall RMSE (mean of folds)", np.mean(mean_rmse_per_fold))
pd.Series(hyp).value_counts()
# Out:
# Fold 0 mean_rmse 38.229135415140234
# Fold 0 individual_rmse 44.687383832605576
# Fold 1 mean_rmse 33.712001730598224
# Fold 1 individual_rmse 39.69241295781963
# Fold 2 mean_rmse 32.19589244255459
# Fold 2 individual_rmse 37.344568985509284
# Overall RMSE (individual) 40.63105032675418
# Overall RMSE (mean of folds) 34.712343196097684
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# 3    10
# 6     5
# 9     3
# 4     3
# 8     2
# 7     1
# dtype: int64

# %% [markdown]
# ## Manual check (Misc.)

# %%
N = 0
dim = 1
plt.plot()
plt.scatter(tmp_train_Xy[N][0][:,dim], tmp_train_Xy[N][1],label='train')
plt.scatter(tmp_tests_x[N][:,dim], tmp_tests_y[N],label='test')
plt.scatter(tmp_tests_x[N][:,dim], tmp_preds_y[N],label='pred')
plt.legend();

# %% [markdown]
# ## K fold GP-LLS-matern-gp-extra

# %%
path = 'results/raw_gp_lls_matern_gp_extras/'
n_ts = 24

# %%
from scipy.optimize import differential_evolution
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels \
    import ConstantKernel as C, Matern
from sklearn.metrics import mean_squared_error
from gp_extras.kernels import LocalLengthScalesKernel

def de_optimizer(obj_func, initial_theta, bounds):
    res = differential_evolution(lambda x: obj_func(x, eval_gradient=False),
                                 bounds, maxiter=20, disp=False, polish=False)
    return res.x, obj_func(res.x, eval_gradient=False)

# %%
# Check if works
# !python scripts/process_gp_lls_gp_extras.py 0 0

# %% [markdown]
# ### Training

# %%
# init = time()
# jobs = []
# for fold in range(K):
#     for ts in range(n_ts):
#         jobs.append('python scripts/process_gp_lls_gp_extras.py {0} {1}'.format(ts, fold))

# print('starting',len(jobs),'jobs on',psutil.cpu_count(),'CPUs')
# sleep(1)
# n_splits = len(jobs)//64+1
# for b_id, batch in enumerate(np.array_split(jobs, n_splits)):
#     print('start',b_id+1,'of',n_splits)
#     print('length of batch=',len(batch))
#     os.system(' | '.join(batch))
#     clear_output(wait=True)
#     print('end',b_id+1,'of',n_splits)
# print((time()-init)/60, 'minutes. all fold complete')

# %% [markdown]
# ### RMSE calculation

# %%
path = 'results/raw_gp_lls_matern_gp_extras/'
name = 'gp_extra_matern'
master_df[name] = None
preds = []
tests = []
mean_rmse_per_fold = []
success = []
n_fold_rmse = []
for fold in folds:
    hyp = []
    fold_rmse = []
    tmp_preds_y = []
    tmp_models = []
    tmp_tests_y = []
    tmp_tests_x = []
    tmp_train_Xy = []
    for ts_n, ts in enumerate(df.index.unique()[:n_ts]):
        try:
            tmp = pd.read_pickle(path+'ts_'+str(ts)+'_fold_'+str(fold))
            hyp.append(tmp['best_hyperpara']['N'])
            preds.append(tmp['pred_y'].squeeze())
            tests.append(tmp['test_y'].squeeze())
            tmp_models.append(tmp['best_model'])
            tmp_train_Xy.append(tmp['train_Xy'])
            tmp_tests_x.append(tmp['test_Xy'][0].squeeze())
            tmp_preds_y.append(tmp['pred_y'].squeeze())
            tmp_tests_y.append(tmp['test_y'].squeeze())
            success.append(path+'ts_'+str(ts)+'_fold_'+str(fold))
            fold_rmse.append(mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False))
            master_df.loc[(str(ts_n), str(ts), str(fold)),name] = mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False)
        except:
            pass
    print('Fold',fold,'mean_rmse',np.mean(fold_rmse))
    mean_rmse_per_fold.append(np.mean(fold_rmse))
    print("Fold",fold,'individual_rmse',mean_squared_error(np.array(tmp_tests_y).flatten(), np.array(tmp_preds_y).flatten(), squared=False))
print("Overall RMSE (individual)", mean_squared_error(np.array(tests).flatten(), np.array(preds).flatten(), squared=False))
print("Overall RMSE (mean of folds)", np.mean(mean_rmse_per_fold))
pd.Series(hyp).value_counts()
# Out:
# Fold 0 mean_rmse 30.737429793702756
# Fold 0 individual_rmse 34.94009076581622
# Fold 1 mean_rmse 33.812058655469144
# Fold 1 individual_rmse 38.24714465262943
# Fold 2 mean_rmse 30.490086145478283
# Fold 2 individual_rmse 33.8470096778525
# Overall RMSE (individual) 35.72708627421346
# Overall RMSE (mean of folds) 31.67985819821673
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# 5    5
# 4    5
# 9    4
# 8    4
# 7    4
# 3    2
# dtype: int64

# %% [markdown]
# ## K fold Kriging

# %%
path = 'results/raw_kriging/'
n_ts = 24

# %%
# Check if works
# !python scripts/process_kriging.py 0 0

# %% [markdown]
# ### Training

# %%
init = time()
jobs = []
for fold in range(K):
    for ts in range(n_ts):
        jobs.append('python scripts/process_kriging.py {0} {1}'.format(ts, fold))

print('starting',len(jobs),'jobs on',psutil.cpu_count(),'CPUs')
sleep(1)
n_splits = len(jobs)//64+1
for b_id, batch in enumerate(np.array_split(jobs, n_splits)):
    print('start',b_id+1,'of',n_splits)
    print('length of batch=',len(batch))
    os.system(' | '.join(batch))
    clear_output(wait=True)
    print('end',b_id+1,'of',n_splits)
print((time()-init)/60, 'minutes. all fold complete')
# Out:
# end 2 of 2
# 0.47365198532740277 minutes. all fold complete

# %% [markdown]
# ### RMSE calculation

# %%
path = 'results/raw_kriging/'
name = 'kriging'
master_df[name] = None
preds = []
tests = []
mean_rmse_per_fold = []
success = []
n_fold_rmse = []
for fold in folds:
    hyp = []
    fold_rmse = []
    tmp_preds_y = []
    tmp_models = []
    tmp_tests_y = []
    tmp_tests_x = []
    tmp_train_Xy = []
    for ts_n, ts in enumerate(df.index.unique()[:n_ts]):
        try:
            tmp = pd.read_pickle(path+'ts_'+str(ts)+'_fold_'+str(fold))
            hyp.append(tmp['best_hyperpara']['nlags'])
            preds.append(tmp['pred_y'].squeeze())
            tests.append(tmp['test_y'].squeeze())
            tmp_models.append(tmp['best_model'])
            tmp_train_Xy.append(tmp['train_Xy'])
            tmp_tests_x.append(tmp['test_Xy'][0].squeeze())
            tmp_preds_y.append(tmp['pred_y'].squeeze())
            tmp_tests_y.append(tmp['test_y'].squeeze())
            success.append(path+'ts_'+str(ts)+'_fold_'+str(fold))
            fold_rmse.append(mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False))
            master_df.loc[(str(ts_n), str(ts), str(fold)),name] = mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False)
        except:
            pass
    print('Fold',fold,'mean_rmse',np.mean(fold_rmse))
    mean_rmse_per_fold.append(np.mean(fold_rmse))
    print("Fold",fold,'individual_rmse',mean_squared_error(np.array(tmp_tests_y).flatten(), np.array(tmp_preds_y).flatten(), squared=False))
print("Overall RMSE (individual)", mean_squared_error(np.array(tests).flatten(), np.array(preds).flatten(), squared=False))
print("Overall RMSE (mean of folds)", np.mean(mean_rmse_per_fold))
pd.Series(hyp).value_counts()
# Out:
# Fold 0 mean_rmse 24.47400965537628
# Fold 0 individual_rmse 27.275423446681934
# Fold 1 mean_rmse 20.663110227523152
# Fold 1 individual_rmse 23.940982631502475
# Fold 2 mean_rmse 23.25255249355037
# Fold 2 individual_rmse 25.148851672296836
# Overall RMSE (individual) 25.49237869111013
# Overall RMSE (mean of folds) 22.796557458816597
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# 9    6
# 8    6
# 6    3
# 3    3
# 7    2
# 5    2
# 4    2
# dtype: int64

# %% [markdown]
# ## K fold GP - RBF

# %%
path = 'results/raw_gp_rbf/'
n_ts = 24

# %%
# Check if works
# !python scripts/process_gp_rbf.py 0 0

# %% [markdown]
# ### Training

# %%
init = time()
jobs = []
for fold in range(K):
    for ts in range(n_ts):
        jobs.append('python scripts/process_gp_rbf.py {0} {1}'.format(ts, fold))

print('starting',len(jobs),'jobs on',psutil.cpu_count(),'CPUs')
sleep(1)
n_splits = len(jobs)//64+1
for b_id, batch in enumerate(np.array_split(jobs, n_splits)):
    print('start',b_id+1,'of',n_splits)
    print('length of batch=',len(batch))
    os.system(' | '.join(batch))
    clear_output(wait=True)
    print('end',b_id+1,'of',n_splits)
print((time()-init)/60, 'minutes. all fold complete')
# Out:
# end 2 of 2
# 0.8233865380287171 minutes. all fold complete

# %% [markdown]
# ### RMSE calculation

# %%
path = 'results/raw_gp_rbf/'
name = 'stat_gp_rbf'
master_df[name] = None
preds = []
tests = []
mean_rmse_per_fold = []
success = []
n_fold_rmse = []
for fold in folds:
    hyp = []
    fold_rmse = []
    tmp_preds_y = []
    tmp_models = []
    tmp_tests_y = []
    tmp_tests_x = []
    tmp_train_Xy = []
    for ts_n, ts in enumerate(df.index.unique()[:n_ts]):
        try:
            tmp = pd.read_pickle(path+'ts_'+str(ts)+'_fold_'+str(fold))
            hyp.append(tmp['best_hyperpara']['ls_init'])
            preds.append(tmp['pred_y'].squeeze())
            tests.append(tmp['test_y'].squeeze())
            tmp_models.append(tmp['best_model'])
            tmp_train_Xy.append(tmp['train_Xy'])
            tmp_tests_x.append(tmp['test_Xy'][0].squeeze())
            tmp_preds_y.append(tmp['pred_y'].squeeze())
            tmp_tests_y.append(tmp['test_y'].squeeze())
            success.append(path+'ts_'+str(ts)+'_fold_'+str(fold))
            fold_rmse.append(mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False))
            master_df.loc[(str(ts_n), str(ts), str(fold)),name] = mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False)
        except:
            pass
    print('Fold',fold,'mean_rmse',np.mean(fold_rmse))
    mean_rmse_per_fold.append(np.mean(fold_rmse))
    print("Fold",fold,'individual_rmse',mean_squared_error(np.array(tmp_tests_y).flatten(), np.array(tmp_preds_y).flatten(), squared=False))
print("Overall RMSE (individual)", mean_squared_error(np.array(tests).flatten(), np.array(preds).flatten(), squared=False))
print("Overall RMSE (mean of folds)", np.mean(mean_rmse_per_fold))
pd.Series(hyp).value_counts()
# Out:
# Fold 0 mean_rmse 23.76587720231541
# Fold 0 individual_rmse 26.610777278549186
# Fold 1 mean_rmse 18.763100664774672
# Fold 1 individual_rmse 21.57029630698414
# Fold 2 mean_rmse 23.061756002838482
# Fold 2 individual_rmse 24.955738292569148
# Overall RMSE (individual) 24.469028204833727
# Overall RMSE (mean of folds) 21.863577956642853
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# 100.0    15
# 1.0       4
# 0.1       3
# 10.0      2
# dtype: int64

# %% [markdown]
# ## K fold GP - Matern

# %%
path = 'results/raw_gp_matern/'
n_ts = 24

# %%
# Check if works
# !python scripts/process_gp_matern.py 0 0

# %% [markdown]
# ### Training

# %%
init = time()
jobs = []
for fold in range(K):
    for ts in range(n_ts):
        jobs.append('python scripts/process_gp_matern.py {0} {1}'.format(ts, fold))

print('starting',len(jobs),'jobs on',psutil.cpu_count(),'CPUs')
sleep(1)
n_splits = len(jobs)//64+1
for b_id, batch in enumerate(np.array_split(jobs, n_splits)):
    print('start',b_id+1,'of',n_splits)
    print('length of batch=',len(batch))
    os.system(' | '.join(batch))
    clear_output(wait=True)
    print('end',b_id+1,'of',n_splits)
print((time()-init)/60, 'minutes. all fold complete')
# Out:
# end 2 of 2
# 0.8925134340922037 minutes. all fold complete

# %% [markdown]
# ### RMSE calculation

# %%
path = 'results/raw_gp_matern/'
name = 'stat_gp_matern'
master_df[name] = None
preds = []
tests = []
mean_rmse_per_fold = []
success = []
n_fold_rmse = []
for fold in folds:
    hyp = []
    fold_rmse = []
    tmp_preds_y = []
    tmp_models = []
    tmp_tests_y = []
    tmp_tests_x = []
    tmp_train_Xy = []
    for ts_n, ts in enumerate(df.index.unique()[:n_ts]):
        try:
            tmp = pd.read_pickle(path+'ts_'+str(ts)+'_fold_'+str(fold))
            hyp.append(tmp['best_hyperpara']['ls_init'])
            preds.append(tmp['pred_y'].squeeze())
            tests.append(tmp['test_y'].squeeze())
            tmp_models.append(tmp['best_model'])
            tmp_train_Xy.append(tmp['train_Xy'])
            tmp_tests_x.append(tmp['test_Xy'][0].squeeze())
            tmp_preds_y.append(tmp['pred_y'].squeeze())
            tmp_tests_y.append(tmp['test_y'].squeeze())
            success.append(path+'ts_'+str(ts)+'_fold_'+str(fold))
            fold_rmse.append(mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False))
            master_df.loc[(str(ts_n), str(ts), str(fold)),name] = mean_squared_error(tmp_tests_y[-1], tmp_preds_y[-1], squared=False)
        except:
            pass
    print('Fold',fold,'mean_rmse',np.mean(fold_rmse))
    mean_rmse_per_fold.append(np.mean(fold_rmse))
    print("Fold",fold,'individual_rmse',mean_squared_error(np.array(tmp_tests_y).flatten(), np.array(tmp_preds_y).flatten(), squared=False))
print("Overall RMSE (individual)", mean_squared_error(np.array(tests).flatten(), np.array(preds).flatten(), squared=False))
print("Overall RMSE (mean of folds)", np.mean(mean_rmse_per_fold))
pd.Series(hyp).value_counts()
# Out:
# Fold 0 mean_rmse 23.042371974442414
# Fold 0 individual_rmse 26.20930684232478
# Fold 1 mean_rmse 19.049127576989353
# Fold 1 individual_rmse 21.716335880678145
# Fold 2 mean_rmse 22.634774057374443
# Fold 2 individual_rmse 24.555288494230574
# Overall RMSE (individual) 24.2314479019342
# Overall RMSE (mean of folds) 21.575424536268738
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# /home/patel_zeel/anaconda3/envs/ns/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)
# 100.0    12
# 0.1       5
# 10.0      4
# 1.0       3
# dtype: int64

# %% [markdown]
# ## Appendix and Analysis

# %%
master_df_pruned = master_df.dropna(how='all')

# %%
pd.set_option('display.max_rows', 500)
lets_see = master_df_pruned.sort_values(['lls_matern'], ascending=False)
lets_see
# Out:
#                          lls_matern  \
# 16 2014-05-01 21:00:00 2    102.381
# 8  2014-05-01 12:00:00 2    88.9172
# 13 2014-05-01 17:00:00 1    81.1219
# 8  2014-05-01 12:00:00 1    68.3965
# 13 2014-05-01 17:00:00 0    65.1066
# 17 2014-05-01 22:00:00 0    61.2313
# 15 2014-05-01 19:00:00 2    60.5427
#                        0    58.7628
#                        1    57.0814
# 20 2014-05-02 01:00:00 1    56.1044
# 14 2014-05-01 18:00:00 0    50.9131
# 16 2014-05-01 21:00:00 0    50.6469
# 8  2014-05-01 12:00:00 0    50.5739
# 9  2014-05-01 13:00:00 0    50.0186
# 14 2014-05-01 18:00:00 2    48.0018
# 6  2014-05-01 08:00:00 0    43.6197
#                        2    42.9736
# 16 2014-05-01 21:00:00 1    40.9001
# 17 2014-05-01 22:00:00 1    40.7877
# 13 2014-05-01 17:00:00 2    40.4167
# 4  2014-05-01 06:00:00 0    40.0262
# 12 2014-05-01 16:00:00 2    39.7511
# 5  2014-05-01 07:00:00 2    36.1696
# 17 2014-05-01 22:00:00 2    35.0607
# 4  2014-05-01 06:00:00 2    34.2803
# 10 2014-05-01 14:00:00 0    32.4918
# 6  2014-05-01 08:00:00 1      32.45
# 23 2014-05-08 13:00:00 0    31.9218
# 1  2014-05-01 03:00:00 2    30.1335
#                        1    29.3652
# 14 2014-05-01 18:00:00 1    27.8481
# 20 2014-05-02 01:00:00 0    26.6379
# 10 2014-05-01 14:00:00 2    26.1498
# 0  2014-05-01 02:00:00 1    25.9134
# 7  2014-05-01 09:00:00 0     24.969
# 11 2014-05-01 15:00:00 2    24.9589
# 9  2014-05-01 13:00:00 2    24.7476
#                        1    24.3054
# 5  2014-05-01 07:00:00 0    23.5463
# 3  2014-05-01 05:00:00 0     22.532
# 4  2014-05-01 06:00:00 1     22.246
# 11 2014-05-01 15:00:00 1    21.3773
# 3  2014-05-01 05:00:00 2    21.1856
# 2  2014-05-01 04:00:00 0    21.0065
# 10 2014-05-01 14:00:00 1    20.3011
# 5  2014-05-01 07:00:00 1    19.1483
# 18 2014-05-01 23:00:00 1    18.9133
# 7  2014-05-01 09:00:00 2    18.8304
# 2  2014-05-01 04:00:00 1    17.7588
# 3  2014-05-01 05:00:00 1    17.3669
# 11 2014-05-01 15:00:00 0    17.1488
# 8  2014-05-01 12:00:00 0        47.4946
# 9  2014-05-01 13:00:00 0        16.1237
# 14 2014-05-01 18:00:00 2        30.1241
# 6  2014-05-01 08:00:00 0        35.5912
#                        2         26.775
# 16 2014-05-01 21:00:00 1        25.5415
# 17 2014-05-01 22:00:00 1        18.8385
# 13 2014-05-01 17:00:00 2        30.9324
# 4  2014-05-01 06:00:00 0        18.1742
# 12 2014-05-01 16:00:00 2        17.3767
# 5  2014-05-01 07:00:00 2         23.173
# 17 2014-05-01 22:00:00 2        34.2348
# 4  2014-05-01 06:00:00 2        22.0826
# 10 2014-05-01 14:00:00 0        12.1713
# 6  2014-05-01 08:00:00 1        13.0415
# 23 2014-05-08 13:00:00 0        31.9013
# 1  2014-05-01 03:00:00 2        15.2652
#                        1         12.269
# 14 2014-05-01 18:00:00 1        30.8775
# 20 2014-05-02 01:00:00 0        16.4511
# 10 2014-05-01 14:00:00 2        26.7773
# 0  2014-05-01 02:00:00 1        11.6185
# 7  2014-05-01 09:00:00 0        17.2415
# 11 2014-05-01 15:00:00 2        25.3991
# 9  2014-05-01 13:00:00 2         26.406
#                        1        20.5875
# 5  2014-05-01 07:00:00 0        22.2954
# 3  2014-05-01 05:00:00 0          20.85
# 4  2014-05-01 06:00:00 1        17.8311
# 11 2014-05-01 15:00:00 1        20.7513
# 3  2014-05-01 05:00:00 2        21.4158
# 2  2014-05-01 04:00:00 0        23.0577
# 10 2014-05-01 14:00:00 1        19.1353
# 5  2014-05-01 07:00:00 1        15.8724
# 18 2014-05-01 23:00:00 1        10.7421
# 7  2014-05-01 09:00:00 2        19.5284
# 2  2014-05-01 04:00:00 1        13.4042
# 3  2014-05-01 05:00:00 1        11.4458
# 11 2014-05-01 15:00:00 0        18.3508
# 0  2014-05-01 02:00:00 2        17.4014
# 2  2014-05-01 04:00:00 2        15.6628
# 21 2014-05-02 02:00:00 1        13.3292
# 12 2014-05-01 16:00:00 0        16.2579
# 1  2014-05-01 03:00:00 0        15.7058
# 0  2014-05-01 02:00:00 0        16.3848
# 12 2014-05-01 16:00:00 1        14.6206
# 18 2014-05-01 23:00:00 0        14.2586
# 19 2014-05-02 00:00:00 2        10.1751
# 21 2014-05-02 02:00:00 2        10.1985
# 18 2014-05-01 23:00:00 2        12.8444
# 19 2014-05-02 00:00:00 0        11.0263
#                        1        10.4027
# 23 2014-05-08 13:00:00 2           9.28
# 22 2014-05-02 03:00:00 2        7.37944
#                        0        7.69981
# 21 2014-05-02 02:00:00 0        7.73343
# 22 2014-05-02 03:00:00 1        5.70548
# 7  2014-05-01 09:00:00 1        16.3516
# 23 2014-05-08 13:00:00 1        13.5042
# 20 2014-05-02 01:00:00 2        37.0382

# %%
lets_see.mean()
# Out:
# lls_matern         31.583383
# lls_rbf            34.662811
# gp_extra_matern    31.679858
# kriging            22.796557
# stat_gp_rbf        21.863578
# stat_gp_matern     21.575425
# dtype: float64
